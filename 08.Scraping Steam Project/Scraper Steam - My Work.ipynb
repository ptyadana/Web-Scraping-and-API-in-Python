# %% [markdown]
# # Extracting data from Steam

# %% [markdown]
# ## Initial Setup

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Connect to Steam webpage

# %%
r = requests.get("https://store.steampowered.com/tags/en/Action/")
r.status_code
# Out:
# 200

# %%
html = r.content

# %%
soup = BeautifulSoup(html, "lxml")

# %%
#export as html file

with open ('steam.html','wb') as file:
    file.write(soup.prettify('utf-8'))

# %% [markdown]
# ## What can we scrape from this webpage?
# ## 1) Try extracting the names of the top games from this page.
# ## 2) What tags contain the prices?  Can you extract the price information?
# ## 3) Get all of the header tags on the page
# ## 4) Can you get the text from each span tag with class equal to "top_tag"?
# ## 5) Under the "Narrow by Tag" section, there are a collection of tags (e.g. "Indie", "Adventure", etc.).  Write code to return these tags.
# ## 6) What else can be scraped from this webpage or others on the site?

# %% [markdown]
# ## Now is your turn!

# %% [markdown]
# ----------------

# %% [markdown]
# ## 1) New and Trending Games

# %%
div_new_trending = soup.find_all('div',{'id':"NewReleasesRows"})
div_new_trending
# Out:
# [<div id="NewReleasesRows">
#  <a class="tab_item" data-ds-appid="1253950" data-ds-crtrids="[34832848]" data-ds-itemkey="App_1253950" data-ds-tagids="[19,492,122,113,42804,1646,1684]" href="https://store.steampowered.com/app/1253950/Dreamscaper_Prologue/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1253950,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/1253950/capsule_184x69.jpg?t=1586347340"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="0"><div class="discount_prices"><div class="discount_final_price">Free</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Dreamscaper: Prologue</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, Indie</span><span class="top_tag">, RPG</span><span class="top_tag">, Free to Play</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="952060" data-ds-crtrids="[33273264]" data-ds-descids="[2,5]" data-ds-itemkey="App_952060" data-ds-tagids="[19,1659,1667,3978,3859,7208,5708]" href="https://store.steampowered.com/app/952060/RESIDENT_EVIL_3/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:952060,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/952060/capsule_184x69.jpg?t=1586140111"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="5999"><div class="discount_prices"><div class="discount_final_price">$59.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">RESIDENT EVIL 3</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, Zombies</span><span class="top_tag">, Horror</span><span class="top_tag">, Survival Horror</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="1089090" data-ds-crtrids="[33042543]" data-ds-itemkey="App_1089090" data-ds-tagids="[19,4085,1685,3843,1743,3859,1646]" href="https://store.steampowered.com/app/1089090/ONE_PIECE_PIRATE_WARRIORS_4/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1089090,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/1089090/capsule_184x69.jpg?t=1585532796"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="5999"><div class="discount_prices"><div class="discount_final_price">$59.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">ONE PIECE: PIRATE WARRIORS 4</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, Anime</span><span class="top_tag">, Co-op</span><span class="top_tag">, Online Co-Op</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="923570" data-ds-itemkey="App_923570" data-ds-tagids="[19,21,122,4085,7208,493,4434]" href="https://store.steampowered.com/app/923570/Eternal_Radiance/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:923570,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/923570/capsule_184x69.jpg?t=1586858500"/>
#  </div>
#  <div class="discount_block tab_item_discount" data-price-final="1619"><div class="discount_pct">-10%</div><div class="discount_prices"><div class="discount_original_price">$17.99</div><div class="discount_final_price">$16.19</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Eternal Radiance</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, Adventure</span><span class="top_tag">, RPG</span><span class="top_tag">, Anime</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="895400" data-ds-descids="[2,5]" data-ds-itemkey="App_895400" data-ds-tagids="[128,19,21,492,493,1662,4345]" href="https://store.steampowered.com/app/895400/Deadside/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:895400,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/895400/capsule_184x69.jpg?t=1586887959"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="1999"><div class="discount_prices"><div class="discount_final_price">$19.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Deadside</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Massively Multiplayer</span><span class="top_tag">, Action</span><span class="top_tag">, Adventure</span><span class="top_tag">, Indie</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="835570" data-ds-descids="[2,5]" data-ds-itemkey="App_835570" data-ds-tagids="[9,128,19,599,122,4345,4667]" href="https://store.steampowered.com/app/835570/Conquerors_Blade/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:835570,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/835570/capsule_184x69.jpg?t=1586239508"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="0"><div class="discount_prices"><div class="discount_final_price">Free to Play</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Conqueror's Blade</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Strategy</span><span class="top_tag">, Massively Multiplayer</span><span class="top_tag">, Action</span><span class="top_tag">, Simulation</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="397540" data-ds-crtrids="[2428135,33338128]" data-ds-descids="[1,2,5]" data-ds-itemkey="App_397540" data-ds-tagids="[122,19,3843,353880,1774,4508,1663]" href="https://store.steampowered.com/app/397540/Borderlands_3/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:397540,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/397540/capsule_184x69.jpg?t=1585762880"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="5999"><div class="discount_prices"><div class="discount_final_price">$59.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Borderlands 3</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">RPG</span><span class="top_tag">, Action</span><span class="top_tag">, Online Co-Op</span><span class="top_tag">, Looter Shooter</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="1090630" data-ds-crtrids="[33144221]" data-ds-itemkey="App_1090630" data-ds-tagids="[19,4085,1743,4736,1775,3878,122]" href="https://store.steampowered.com/app/1090630/Granblue_Fantasy_Versus/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1090630,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/1090630/capsule_184x69.jpg?t=1586829205"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="5999"><div class="discount_prices"><div class="discount_final_price">$59.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Granblue Fantasy: Versus</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, Anime</span><span class="top_tag">, Fighting</span><span class="top_tag">, 2D Fighter</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="1129310" data-ds-descids="[5]" data-ds-itemkey="App_1129310" data-ds-tagids="[599,492,19,1774,4175,1663,1036]" href="https://store.steampowered.com/app/1129310/Receiver_2/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1129310,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/1129310/capsule_184x69.jpg?t=1586889933"/>
#  </div>
#  <div class="discount_block tab_item_discount" data-price-final="1799"><div class="discount_pct">-10%</div><div class="discount_prices"><div class="discount_original_price">$19.99</div><div class="discount_final_price">$17.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Receiver 2</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">Simulation</span><span class="top_tag">, Indie</span><span class="top_tag">, Action</span><span class="top_tag">, Shooter</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="1218740" data-ds-itemkey="App_1218740" data-ds-tagids="[19,122,113,9,1775,4172,4161]" href="https://store.steampowered.com/app/1218740/Rakion_Chaos_Force/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1218740,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/1218740/capsule_184x69.jpg?t=1586826517"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="0"><div class="discount_prices"><div class="discount_final_price">Free</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Rakion Chaos Force</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, RPG</span><span class="top_tag">, Free to Play</span><span class="top_tag">, Strategy</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="261550" data-ds-crtrids="[33089344]" data-ds-descids="[5]" data-ds-itemkey="App_261550" data-ds-tagids="[493,4172,9,1695,122,1678,3859]" href="https://store.steampowered.com/app/261550/Mount__Blade_II_Bannerlord/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:261550,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/261550/capsule_184x69.jpg?t=1586885335"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="4999"><div class="discount_prices"><div class="discount_final_price">$49.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Mount &amp; Blade II: Bannerlord</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Early Access</span><span class="top_tag">, Medieval</span><span class="top_tag">, Strategy</span><span class="top_tag">, Open World</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="546560" data-ds-crtrids="[4,33078398]" data-ds-descids="[2,5]" data-ds-itemkey="App_546560" data-ds-tagids="[5144,19,21978,21,7208,4166,1742]" href="https://store.steampowered.com/app/546560/HalfLife_Alyx/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:546560,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/546560/capsule_184x69.jpg?t=1584985275"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="5999"><div class="discount_prices"><div class="discount_final_price">$59.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Half-Life: Alyx</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="vr_required">VR Only</span> <div class="tab_item_top_tags"><span class="top_tag">Masterpiece</span><span class="top_tag">, Action</span><span class="top_tag">, VR</span><span class="top_tag">, Adventure</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="903950" data-ds-descids="[2,5]" data-ds-itemkey="App_903950" data-ds-tagids="[128,1662,19,21,122,492,1695]" href="https://store.steampowered.com/app/903950/Last_Oasis/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:903950,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/903950/capsule_184x69.jpg?t=1586454736"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="2999"><div class="discount_prices"><div class="discount_final_price">$29.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">Last Oasis</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Massively Multiplayer</span><span class="top_tag">, Survival</span><span class="top_tag">, Action</span><span class="top_tag">, Adventure</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="782330" data-ds-crtrids="[33028765,35501448]" data-ds-descids="[2,5]" data-ds-itemkey="App_782330" data-ds-tagids="[19,5144,1756,1663,4345,4667,9541]" href="https://store.steampowered.com/app/782330/DOOM_Eternal/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:782330,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/782330/capsule_184x69.jpg?t=1585834350"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="5999"><div class="discount_prices"><div class="discount_final_price">$59.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">DOOM Eternal</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, Masterpiece</span><span class="top_tag">, Great Soundtrack</span><span class="top_tag">, FPS</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  <a class="tab_item" data-ds-appid="960690" data-ds-crtrids="[6869120]" data-ds-itemkey="App_960690" data-ds-tagids="[19,9,492,21,32322,3964,3959]" href="https://store.steampowered.com/app/960690/One_Step_From_Eden/?snr=1_241_4_action_103" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:960690,&quot;params&quot;:{&quot;bDisableHover&quot;:false},&quot;public&quot;:1,&quot;v6&quot;:1} );">
#  <div class="tab_item_cap">
#  <img class="tab_item_cap_img" src="https://steamcdn-a.akamaihd.net/steam/apps/960690/capsule_184x69.jpg?t=1585832836"/>
#  </div>
#  <div class="discount_block tab_item_discount no_discount" data-price-final="1999"><div class="discount_prices"><div class="discount_final_price">$19.99</div></div></div> <div class="tab_item_content">
#  <div class="tab_item_name">One Step From Eden</div>
#  <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, Strategy</span><span class="top_tag">, Indie</span><span class="top_tag">, Adventure</span></div>
#  </div>
#  </div>
#  <div style="clear: both;"></div>
#  </a>
#  </div>]

# %% [markdown]
# ### 1) New and Trending Games - Names

# %%
new_trending_games_name_list = [div.text for div in div_new_trending[0].find_all('div',{'class':'tab_item_name'})]
new_trending_games_name_list
# Out:
# ['Dreamscaper: Prologue',
#  'RESIDENT EVIL 3',
#  'ONE PIECE: PIRATE WARRIORS 4',
#  'Eternal Radiance',
#  'Deadside',
#  "Conqueror's Blade",
#  'Borderlands 3',
#  'Granblue Fantasy: Versus',
#  'Receiver 2',
#  'Rakion Chaos Force',
#  'Mount & Blade II: Bannerlord',
#  'Half-Life: Alyx',
#  'Last Oasis',
#  'DOOM Eternal',
#  'One Step From Eden']

# %% [markdown]
# ### 2) New and Trending Games - Price

# %%
new_trending_games_price_list = [div.text for div in div_new_trending[0].find_all('div',{'class':'discount_final_price'})]
new_trending_games_price_list
# Out:
# ['Free',
#  '$59.99',
#  '$59.99',
#  '$16.19',
#  '$19.99',
#  'Free to Play',
#  '$59.99',
#  '$59.99',
#  '$17.99',
#  'Free',
#  '$49.99',
#  '$59.99',
#  '$29.99',
#  '$59.99',
#  '$19.99']

# %% [markdown]
# ### New and Trending Games - Tags

# %%
new_trending_games_tags_list = [div.text for div in div_new_trending[0].find_all('div',{'class':'tab_item_top_tags'})]
new_trending_games_tags_list
# Out:
# ['Action, Indie, RPG, Free to Play',
#  'Action, Zombies, Horror, Survival Horror',
#  'Action, Anime, Co-op, Online Co-Op',
#  'Action, Adventure, RPG, Anime',
#  'Massively Multiplayer, Action, Adventure, Indie',
#  'Strategy, Massively Multiplayer, Action, Simulation',
#  'RPG, Action, Online Co-Op, Looter Shooter',
#  'Action, Anime, Fighting, 2D Fighter',
#  'Simulation, Indie, Action, Shooter',
#  'Action, RPG, Free to Play, Strategy',
#  'Early Access, Medieval, Strategy, Open World',
#  'Masterpiece, Action, VR, Adventure',
#  'Massively Multiplayer, Survival, Action, Adventure',
#  'Action, Masterpiece, Great Soundtrack, FPS',
#  'Action, Strategy, Indie, Adventure']

# %% [markdown]
# ### Representing data using Pandas

# %%
import pandas as pd

# %%
new_trending_games_info = pd.DataFrame()

new_trending_games_info['Title'] = new_trending_games_name_list
new_trending_games_info['Price'] = new_trending_games_price_list
new_trending_games_info ['Tags'] = new_trending_games_tags_list

new_trending_games_info
# Out:
#                                  Title         Price  \
# 0                Dreamscaper: Prologue          Free
# 1                      RESIDENT EVIL 3        $59.99
# 2         ONE PIECE: PIRATE WARRIORS 4        $59.99
# 3                     Eternal Radiance        $16.19
# 4                             Deadside        $19.99
# 5                    Conqueror's Blade  Free to Play
# 6                        Borderlands 3        $59.99
# 7             Granblue Fantasy: Versus        $59.99
# 8                           Receiver 2        $17.99
# 9                   Rakion Chaos Force          Free
# 10        Mount & Blade II: Bannerlord        $49.99
# 11                     Half-Life: Alyx        $59.99
# 12                          Last Oasis        $29.99
# 13                        DOOM Eternal        $59.99
# 14  Disaster Report 4: Summer Memories        $59.99
#
#                                                  Tags
# 0                    Action, Indie, RPG, Free to Play
# 1            Action, Zombies, Horror, Survival Horror
# 2                  Action, Anime, Co-op, Online Co-Op
# 3                       Action, Adventure, RPG, Anime
# 4     Massively Multiplayer, Action, Adventure, Indie
# 5   Strategy, Massively Multiplayer, Action, Simul...
# 6           RPG, Action, Online Co-Op, Looter Shooter
# 7                 Action, Anime, Fighting, 2D Fighter
# 8                  Simulation, Indie, Action, Shooter
# 9                 Action, RPG, Free to Play, Strategy
# 10       Early Access, Medieval, Strategy, Open World
# 11                 Masterpiece, Action, VR, Adventure
# 12  Massively Multiplayer, Survival, Action, Adven...
# 13         Action, Masterpiece, Great Soundtrack, FPS
# 14                    Adventure, Action, Survival, VR

# %% [markdown]
# ### exporting to csv

# %%
new_trending_games_info.to_csv('New_Trending_Games_Info.csv', index = False, header = True)

# %% [markdown]
# -------------

# %% [markdown]
# ## 2) Getting games info for "Top Sellers", "What's popular", "Top Rated"

# %%
import pandas as pd

game_list_file_names = ['Top_Sellers_Games_info.csv', 'Trending_Games_info.csv', 'Top_Rated_Games.info.csv']
games_info_dataframe_list = []

div_class_list = ['TopSellersRows', 'ConcurrentUsersRows', 'TopRatedRows']
# div_class_list = [ComingSoonRows']
    
for game_type_class in div_class_list:
    
    div_table = soup.find_all('div', attrs={"id": game_type_class})
    
    games_name_list = []
    games_price_list = []
    games_tags_list = []
    
    for div_item in div_table:
        games_name_list = [div.text for div in div_item.find_all('div',{'class':'tab_item_name'})] 
        games_price_list = [div.text for div in div_item.find_all('div',{'class':'discount_final_price'})]
        games_tags_list = [div.text for div in div_item.find_all('div',{'class':'tab_item_top_tags'})]
    
    #setting as dataframe for each game type
    games_info = pd.DataFrame()

    games_info['Title'] = games_name_list
    games_info['Price'] = games_price_list
    games_info ['Tags'] = games_tags_list
    
    games_info_dataframe_list.append(games_info)

#exporting to csv
for i in range(3):
    game_info = games_info_dataframe_list[i]
    games_info.to_csv(game_list_file_names[i], index = False, header = True)

# %% [markdown]
# ----------------

# %% [markdown]
# ## 3) Getting header tags of the page

# %%
game_header_tags_div = soup.find_all('div', {'class':'tab_content'})
game_header_tags_div
# Out:
# [<div class="tab_content">
#  													New and Trending												</div>,
#  <div class="tab_content">
#  													Top Selling												</div>,
#  <div class="tab_content">
#  													What's Popular												</div>,
#  <div class="tab_content">
#  													Top Rated												</div>,
#  <div class="tab_content">
#  													Upcoming												</div>]

# %%
game_header_tags_list = [div.text.strip() for div in game_header_tags_div]
game_header_tags_list
# Out:
# ['New and Trending', 'Top Selling', "What's Popular", 'Top Rated', 'Upcoming']

# %% [markdown]
# -----------

# %% [markdown]
# ## 4) Info of top_tag span

# %%
top_tag_div = soup.find_all('span',{'class':'top_tag'})
top_tag_div
# Out:
# [<span class="top_tag">Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Free to Play</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Zombies</span>,
#  <span class="top_tag">, Horror</span>,
#  <span class="top_tag">, Survival Horror</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Anime</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">, Online Co-Op</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Anime</span>,
#  <span class="top_tag">Massively Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">Strategy</span>,
#  <span class="top_tag">, Massively Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Simulation</span>,
#  <span class="top_tag">RPG</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Online Co-Op</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Anime</span>,
#  <span class="top_tag">, Fighting</span>,
#  <span class="top_tag">, 2D Fighter</span>,
#  <span class="top_tag">Simulation</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Free to Play</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">Early Access</span>,
#  <span class="top_tag">, Medieval</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Masterpiece</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, VR</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">Massively Multiplayer</span>,
#  <span class="top_tag">, Survival</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Masterpiece</span>,
#  <span class="top_tag">, Great Soundtrack</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">, Hunting</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Anime</span>,
#  <span class="top_tag">, Fighting</span>,
#  <span class="top_tag">, 2D Fighter</span>,
#  <span class="top_tag">RPG</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Online Co-Op</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Anime</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">, Online Co-Op</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Zombies</span>,
#  <span class="top_tag">, Horror</span>,
#  <span class="top_tag">, Survival Horror</span>,
#  <span class="top_tag">Co-op</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Souls-like</span>,
#  <span class="top_tag">, Difficult</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Singleplayer</span>,
#  <span class="top_tag">Casual</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Sports</span>,
#  <span class="top_tag">, Rhythm</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Anime</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Masterpiece</span>,
#  <span class="top_tag">, Great Soundtrack</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Tactical</span>,
#  <span class="top_tag">Masterpiece</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, VR</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, Masterpiece</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Military</span>,
#  <span class="top_tag">, Simulation</span>,
#  <span class="top_tag">Looter Shooter</span>,
#  <span class="top_tag">, Free to Play</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">Co-op</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Competitive</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Hero Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Tactical</span>,
#  <span class="top_tag">Survival</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Battle Royale</span>,
#  <span class="top_tag">Looter Shooter</span>,
#  <span class="top_tag">, Free to Play</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">Early Access</span>,
#  <span class="top_tag">, Medieval</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, MOBA</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">Multiplayer</span>,
#  <span class="top_tag">, Soccer</span>,
#  <span class="top_tag">, Competitive</span>,
#  <span class="top_tag">, Sports</span>,
#  <span class="top_tag">RPG</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Online Co-Op</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">Open World Survival Craft</span>,
#  <span class="top_tag">, Survival</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Fighting</span>,
#  <span class="top_tag">, 2D</span>,
#  <span class="top_tag">Hero Shooter</span>,
#  <span class="top_tag">, Free to Play</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">Survival</span>,
#  <span class="top_tag">, Crafting</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Competitive</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Hero Shooter</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Tactical</span>,
#  <span class="top_tag">Looter Shooter</span>,
#  <span class="top_tag">, Free to Play</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">Zombies</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">Loot</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Female Protagonist</span>,
#  <span class="top_tag">, Third Person</span>,
#  <span class="top_tag">Co-op</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Heist</span>,
#  <span class="top_tag">Shooter</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Free to Play</span>,
#  <span class="top_tag">, Looter Shooter</span>,
#  <span class="top_tag">, FPS</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Sci-fi</span>,
#  <span class="top_tag">, Classic</span>,
#  <span class="top_tag">FPS</span>,
#  <span class="top_tag">, Story Rich</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Singleplayer</span>,
#  <span class="top_tag">Medieval</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">Third-Person Shooter</span>,
#  <span class="top_tag">, Action Roguelike</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">Co-op</span>,
#  <span class="top_tag">, Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Simulation</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Crime</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, Pirates</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Exploration</span>,
#  <span class="top_tag">, Space</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">Indie</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Roguelike</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Violent</span>,
#  <span class="top_tag">, Souls-like</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Indie</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">, Casual</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Early Access</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Zombies</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">, Co-op</span>,
#  <span class="top_tag">Indie</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Racing</span>,
#  <span class="top_tag">, Adventure</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, 3D Platformer</span>,
#  <span class="top_tag">, Comedy</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Open World</span>,
#  <span class="top_tag">Action</span>,
#  <span class="top_tag">, Strategy</span>,
#  <span class="top_tag">, Arena Shooter</span>,
#  <span class="top_tag">, Shooter</span>,
#  <span class="top_tag">Adventure</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Massively Multiplayer</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">Massively Multiplayer</span>,
#  <span class="top_tag">, RPG</span>,
#  <span class="top_tag">, Action</span>,
#  <span class="top_tag">, Violent</span>]

# %%
top_tag_list = [div.text.strip(', ') for div in top_tag_div]
top_tag_list
# Out:
# ['Action',
#  'Indie',
#  'RPG',
#  'Free to Play',
#  'Action',
#  'Zombies',
#  'Horror',
#  'Survival Horror',
#  'Action',
#  'Anime',
#  'Co-op',
#  'Online Co-Op',
#  'Action',
#  'Adventure',
#  'RPG',
#  'Anime',
#  'Massively Multiplayer',
#  'Action',
#  'Adventure',
#  'Indie',
#  'Strategy',
#  'Massively Multiplayer',
#  'Action',
#  'Simulation',
#  'RPG',
#  'Action',
#  'Online Co-Op',
#  'Looter Shooter',
#  'Action',
#  'Anime',
#  'Fighting',
#  '2D Fighter',
#  'Simulation',
#  'Indie',
#  'Action',
#  'Shooter',
#  'Action',
#  'RPG',
#  'Free to Play',
#  'Strategy',
#  'Early Access',
#  'Medieval',
#  'Strategy',
#  'Open World',
#  'Masterpiece',
#  'Action',
#  'VR',
#  'Adventure',
#  'Massively Multiplayer',
#  'Survival',
#  'Action',
#  'Adventure',
#  'Action',
#  'Masterpiece',
#  'Great Soundtrack',
#  'FPS',
#  'Action',
#  'Strategy',
#  'Indie',
#  'Adventure',
#  'Action',
#  'Multiplayer',
#  'Co-op',
#  'Hunting',
#  'Action',
#  'Anime',
#  'Fighting',
#  '2D Fighter',
#  'RPG',
#  'Action',
#  'Online Co-Op',
#  'Looter Shooter',
#  'Action',
#  'Anime',
#  'Co-op',
#  'Online Co-Op',
#  'Action',
#  'Zombies',
#  'Horror',
#  'Survival Horror',
#  'Co-op',
#  'Multiplayer',
#  'Action',
#  'Open World',
#  'Souls-like',
#  'Difficult',
#  'Action',
#  'Singleplayer',
#  'Casual',
#  'Action',
#  'Sports',
#  'Rhythm',
#  'Action',
#  'RPG',
#  'Anime',
#  'Open World',
#  'Action',
#  'Masterpiece',
#  'Great Soundtrack',
#  'FPS',
#  'Action',
#  'FPS',
#  'Multiplayer',
#  'Tactical',
#  'Masterpiece',
#  'Action',
#  'VR',
#  'Adventure',
#  'Adventure',
#  'Action',
#  'Open World',
#  'Masterpiece',
#  'Action',
#  'Multiplayer',
#  'Military',
#  'Simulation',
#  'Looter Shooter',
#  'Free to Play',
#  'Action',
#  'Co-op',
#  'Co-op',
#  'Multiplayer',
#  'Action',
#  'Open World',
#  'FPS',
#  'Shooter',
#  'Multiplayer',
#  'Competitive',
#  'FPS',
#  'Hero Shooter',
#  'Multiplayer',
#  'Tactical',
#  'Survival',
#  'Shooter',
#  'Multiplayer',
#  'Battle Royale',
#  'Looter Shooter',
#  'Free to Play',
#  'Action',
#  'Co-op',
#  'Action',
#  'FPS',
#  'Multiplayer',
#  'Shooter',
#  'Early Access',
#  'Medieval',
#  'Strategy',
#  'Open World',
#  'Free to Play',
#  'Looter Shooter',
#  'FPS',
#  'Multiplayer',
#  'Free to Play',
#  'MOBA',
#  'Multiplayer',
#  'Strategy',
#  'Multiplayer',
#  'Soccer',
#  'Competitive',
#  'Sports',
#  'RPG',
#  'Action',
#  'Online Co-Op',
#  'Looter Shooter',
#  'Open World Survival Craft',
#  'Survival',
#  'Open World',
#  'Multiplayer',
#  'Free to Play',
#  'Multiplayer',
#  'Fighting',
#  '2D',
#  'Hero Shooter',
#  'Free to Play',
#  'Multiplayer',
#  'FPS',
#  'Survival',
#  'Crafting',
#  'Multiplayer',
#  'Open World',
#  'FPS',
#  'Shooter',
#  'Multiplayer',
#  'Competitive',
#  'FPS',
#  'Hero Shooter',
#  'Multiplayer',
#  'Tactical',
#  'Looter Shooter',
#  'Free to Play',
#  'Action',
#  'Co-op',
#  'Zombies',
#  'Co-op',
#  'FPS',
#  'Multiplayer',
#  'Action',
#  'FPS',
#  'Multiplayer',
#  'Shooter',
#  'Loot',
#  'Shooter',
#  'Action',
#  'Multiplayer',
#  'Adventure',
#  'Action',
#  'Female Protagonist',
#  'Third Person',
#  'Co-op',
#  'Action',
#  'FPS',
#  'Heist',
#  'Shooter',
#  'Action',
#  'FPS',
#  'Multiplayer',
#  'Free to Play',
#  'Looter Shooter',
#  'FPS',
#  'Multiplayer',
#  'FPS',
#  'Action',
#  'Sci-fi',
#  'Classic',
#  'FPS',
#  'Story Rich',
#  'Action',
#  'Singleplayer',
#  'Medieval',
#  'RPG',
#  'Open World',
#  'Strategy',
#  'Third-Person Shooter',
#  'Action Roguelike',
#  'Action',
#  'Multiplayer',
#  'Co-op',
#  'Multiplayer',
#  'Action',
#  'Open World',
#  'Simulation',
#  'Action',
#  'Indie',
#  'Crime',
#  'Adventure',
#  'Action',
#  'Open World',
#  'Pirates',
#  'Adventure',
#  'Action',
#  'Exploration',
#  'Space',
#  'Action',
#  'RPG',
#  'Indie',
#  'Adventure',
#  'Indie',
#  'Action',
#  'Adventure',
#  'Roguelike',
#  'Action',
#  'RPG',
#  'Violent',
#  'Souls-like',
#  'Action',
#  'Indie',
#  'Adventure',
#  'Casual',
#  'Adventure',
#  'Action',
#  'Early Access',
#  'RPG',
#  'Action',
#  'Zombies',
#  'Open World',
#  'Co-op',
#  'Indie',
#  'Action',
#  'Racing',
#  'Adventure',
#  'Adventure',
#  'Action',
#  '3D Platformer',
#  'Comedy',
#  'Adventure',
#  'RPG',
#  'Action',
#  'Open World',
#  'Action',
#  'Strategy',
#  'Arena Shooter',
#  'Shooter',
#  'Adventure',
#  'RPG',
#  'Massively Multiplayer',
#  'Action',
#  'Massively Multiplayer',
#  'RPG',
#  'Action',
#  'Violent']

# %%
unique_top_tags = set(top_tag_list)
unique_top_tags
# Out:
# {'2D',
#  '2D Fighter',
#  '3D Platformer',
#  'Action',
#  'Action Roguelike',
#  'Adventure',
#  'Anime',
#  'Arena Shooter',
#  'Battle Royale',
#  'Casual',
#  'Classic',
#  'Co-op',
#  'Comedy',
#  'Competitive',
#  'Crafting',
#  'Crime',
#  'Difficult',
#  'Early Access',
#  'Exploration',
#  'FPS',
#  'Female Protagonist',
#  'Fighting',
#  'Free to Play',
#  'Great Soundtrack',
#  'Heist',
#  'Hero Shooter',
#  'Horror',
#  'Hunting',
#  'Indie',
#  'Loot',
#  'Looter Shooter',
#  'MOBA',
#  'Massively Multiplayer',
#  'Masterpiece',
#  'Medieval',
#  'Military',
#  'Multiplayer',
#  'Online Co-Op',
#  'Open World',
#  'Open World Survival Craft',
#  'Pirates',
#  'RPG',
#  'Racing',
#  'Rhythm',
#  'Roguelike',
#  'Sci-fi',
#  'Shooter',
#  'Simulation',
#  'Singleplayer',
#  'Soccer',
#  'Souls-like',
#  'Space',
#  'Sports',
#  'Story Rich',
#  'Strategy',
#  'Survival',
#  'Survival Horror',
#  'Tactical',
#  'Third Person',
#  'Third-Person Shooter',
#  'VR',
#  'Violent',
#  'Zombies'}

# %% [markdown]
# ------------------

# %% [markdown]
# ## 5) Narrow By Tag section tags

# %%
narrow_by_tag_list = [div.text for div in soup.find_all('span', {'class':'tag_name'})]
narrow_by_tag_list
# Out:
# ['Indie',
#  'Adventure',
#  'Casual',
#  'Singleplayer',
#  'RPG',
#  'Early Access',
#  'Simulation',
#  'Strategy',
#  'Multiplayer',
#  '2D',
#  'Violent',
#  'Shooter']
