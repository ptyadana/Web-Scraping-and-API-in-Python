# %% [markdown]
# # Scraping SoundCoud

# %% [markdown]
# ## Initial Setup

# %%
# import packages
import requests
from bs4 import BeautifulSoup

# %%
from requests_html import AsyncHTMLSession

# %%
session = AsyncHTMLSession()

# %% [markdown]
# ## Connect to SoundCloud

# %%
# make connection to webpage
resp = requests.get("https://soundcloud.com/discover")

# %%
# get HTML from response object
html = resp.content

# %%
# convert HTML to BeautifulSoup object
soup = BeautifulSoup(html, "lxml")

# %% [markdown]
# ## Get links on the webpage.  Notice how this doesn't extract all the links visible on the webpage...what can we do about that?

# %%
links = soup.find_all("a")
links
# Out:
# [<a class="header__logoLink sc-border-box sc-ir" href="/" title="Home">SoundCloud</a>,
#  <a class="sc-button sc-button-medium" href="http://www.enable-javascript.com/" target="_blank">Show me how to enable it</a>,
#  <a href="https://help.soundcloud.com/hc/articles/115003564308-Technical-requirements">Need help?</a>,
#  <a href="http://google.com/chrome" target="_blank" title="Chrome">Chrome</a>,
#  <a href="http://firefox.com" target="_blank" title="Firefox">Firefox</a>,
#  <a href="http://apple.com/safari" target="_blank" title="Safari">Safari</a>,
#  <a href="http://windows.microsoft.com/ie" target="_blank" title="Internet Explorer">Internet Explorer</a>,
#  <a class="sc-button" href="https://help.soundcloud.com" id="try-again" target="_blank">I need help</a>,
#  <a href="/popular/searches" title="Popular searches">Popular searches</a>]

# %% [markdown]
# ## 1) Use requests-html to extract other links on the page by executing JavaScript.  How many links do you see now?
# ## 2) After you complete 1), get the text of the new paragraphs now visible in the HTML.
# ## 3) Try out a few other tags - what else appears after executing the JavaScript?
# ## 4) Using a CSS selector, extract the meta tag with name = "keywords".  Can you get this tag's attributes?
# ## 5) Links that automatically open to a new a tab are identified by having a "target" attribute equal to "_blank".  Try extracting these links and their URLs.

# %% [markdown]
# ----------

# %% [markdown]
# ## 1) Use requests-html to extract other links on the page by executing JavaScript

# %%
#using dynamically generated JS page

r = await session.get("https://soundcloud.com/discover")

# %%
r.status_code
# Out:
# 200

# %%
await r.html.arender()

# %%
new_links = r.html.find('a')
new_links
# Out:
# [<Element 'a' href='/' title='Home' class=('header__logoLink', 'header__logoLink-iconOnly', 'sc-border-box', 'sc-ir')>,
#  <Element 'a' href='/' title='Home' class=('header__logoLink', 'header__logoLink-wordmark', 'sc-border-box', 'sc-ir')>,
#  <Element 'a' class=('header__navMenuItem',) data-menu-name='home' href='/discover'>,
#  <Element 'a' class=('header__navMenuItem',) data-menu-name='stream' href='/stream'>,
#  <Element 'a' class=('header__navMenuItem',) data-menu-name='library' href='/you/library'>,
#  <Element 'a' href='/upload' class=('uploadButton', 'header__link') tabindex='0'>,
#  <Element 'a' href='' class=('header__moreButton', 'sc-ir') tabindex='0' aria-haspopup='true' role='button' aria-owns='dropdown-button-98'>,
#  <Element 'a' href='/pages/cookies' class=('sc-link-dark',)>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/capitalcqu/sets/midnight-lofi'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/capitalcqu/sets/midnight-lofi'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/capitalcqu'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/mightyj-1/sets/morning-chillout'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/mightyj-1/sets/morning-chillout'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/mightyj-1'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/user-876658341/sets/sunday-morning-kisses-and'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/user-876658341/sets/sunday-morning-kisses-and'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/user-876658341'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/lovelovesyousoo/sets/jazzhip7c'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/lovelovesyousoo/sets/jazzhip7c'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/lovelovesyousoo'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/user-876658341/sets/sunday-music-and-hot-coffee'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/user-876658341/sets/sunday-music-and-hot-coffee'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/user-876658341'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/digitalstreams/sets/deephousehits'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/digitalstreams/sets/deephousehits'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/digitalstreams'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/user-610681392/sets/summer-2k17'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/user-610681392/sets/summer-2k17'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/user-610681392'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/mugatunesofficial/sets/pure-adrenaline'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/mugatunesofficial/sets/pure-adrenaline'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/mugatunesofficial'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/jafeel/sets/tomorrowland'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/jafeel/sets/tomorrowland'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/jafeel'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/teamdr/sets/noise-basement'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/teamdr/sets/noise-basement'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/teamdr'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/lovelovesyousoo/sets/beautyinside'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/lovelovesyousoo/sets/beautyinside'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/lovelovesyousoo'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/capitalcqu/sets/midnight-lofi'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/capitalcqu/sets/midnight-lofi'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/capitalcqu'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/rehan-khan-55/sets/meditation'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/rehan-khan-55/sets/meditation'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/rehan-khan-55'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/rehab-mohammed/sets/relax'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/rehab-mohammed/sets/relax'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/rehab-mohammed'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/user-961145082/sets/as-beautiful-as-it-sounds'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/user-961145082/sets/as-beautiful-as-it-sounds'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/user-961145082'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/agamidae/sets/instrumental-7'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/agamidae/sets/instrumental-7'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/agamidae'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/nitza-md/sets/piano-deep-concentration'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/nitza-md/sets/piano-deep-concentration'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/nitza-md'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/mzn665/sets/coffeehouse'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/mzn665/sets/coffeehouse'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/mzn665'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/itsulana/sets/read-more-write-more'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/itsulana/sets/read-more-write-more'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/itsulana'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/lovelovesyousoo/sets/jazz-hip'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/lovelovesyousoo/sets/jazz-hip'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/lovelovesyousoo'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/ilyanaazman/sets/tsyn'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/ilyanaazman/sets/tsyn'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/ilyanaazman'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/mugatunesofficial/sets/pure-adrenaline'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/mugatunesofficial/sets/pure-adrenaline'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/mugatunesofficial'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/fitnation-egypt/sets/jointhefitnation'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/fitnation-egypt/sets/jointhefitnation'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/fitnation-egypt'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/partyplaylists69/sets/workout-2018'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/partyplaylists69/sets/workout-2018'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/partyplaylists69'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/goldsgymegypt/sets/dubstep-by-golds-gym-egypt'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/goldsgymegypt/sets/dubstep-by-golds-gym-egypt'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/goldsgymegypt'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/rehab-mohammed/sets/relax'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/rehab-mohammed/sets/relax'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/rehab-mohammed'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/billie-kihega/sets/billies-sleep-sounds'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/billie-kihega/sets/billies-sleep-sounds'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/billie-kihega'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/jean-claude-4/sets/sleep-healing-sounds'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/jean-claude-4/sets/sleep-healing-sounds'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/jean-claude-4'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/lolollov2/sets/cosy-night-autumn'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/lolollov2/sets/cosy-night-autumn'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/lolollov2'>,
#  <Element 'a' class=('playableTile__artworkLink', 'audibleTile__artworkLink') href='/egemannen/sets/bed-bug-classic-ii'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play' draggable='true'>,
#  <Element 'a' class=('sc-link-dark', 'sc-type-light', 'playableTile__mainHeading', 'audibleTile__mainHeading', 'playableTile__heading', 'playableTile__audibleHeading', 'audibleTile__audibleHeading', 'sc-truncate', 'sc-font-light') href='/egemannen/sets/bed-bug-classic-ii'>,
#  <Element 'a' class=('sc-link-light', 'playableTile__usernameHeading', 'audibleTile__usernameHeading', 'sc-truncate') href='/egemannen'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-trending:all-music'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-trending:all-music'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-trending:alternativerock'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-trending:alternativerock'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-trending:ambient'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-trending:ambient'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-trending:classical'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-trending:classical'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-trending:country'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-trending:country'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-top:all-music'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-top:all-music'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-top:alternativerock'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-top:alternativerock'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-top:ambient'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-top:ambient'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-top:classical'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-top:classical'>,
#  <Element 'a' class=('playableTile__artworkLink',) href='/discover/sets/charts-top:country'>,
#  <Element 'a' role='button' href='' class=('sc-button-play', 'playButton', 'sc-button', 'm-stretch') tabindex='0' title='Play'>,
#  <Element 'a' class=('playableTile__heading', 'playableTile__mainHeading', 'playableTile__audibleHeading', 'sc-truncate', 'sc-type-light', 'sc-font-light', 'sc-link-dark') href='/discover/sets/charts-top:country'>,
#  <Element 'a' href='https://itunes.apple.com/us/app/soundcloud/id336353151?mt=8' target='_blank' class=('mobileAppsButtons__button', 'mobileAppsButtons__appStore', 'g-appStoreButton', 'g-appStoreButton__appStore', 'sc-ir')>,
#  <Element 'a' href='https://play.google.com/store/apps/details?id=com.soundcloud.android&hl=us&referrer=utm_source%3Dsoundcloud%26utm_medium%3Dweb%26utm_campaign%3Dweb_xsell_discover_page' target='_blank' class=('mobileAppsButtons__button', 'mobileAppsButtons__googlePlay', 'g-appStoreButton', 'g-appStoreButton__googlePlay', 'sc-ir')>,
#  <Element 'a' class=('sc-link-verylight',) href='/terms-of-use' title='Terms of use'>,
#  <Element 'a' class=('sc-link-verylight',) href='/pages/privacy' title='Privacy policy'>,
#  <Element 'a' class=('sc-link-verylight',) href='/pages/cookies' title='Cookies policy'>,
#  <Element 'a' class=('sc-link-verylight',) href='/imprint' title='Company information'>,
#  <Element 'a' class=('sc-link-verylight',) href='//creators.soundcloud.com' target='_blank' title='Creator Resources'>,
#  <Element 'a' class=('sc-link-verylight',) href='//blog.soundcloud.com' target='_blank' title='SoundCloud blog'>,
#  <Element 'a' class=('sc-link-verylight',) href='/charts/top' title='Charts'>,
#  <Element 'a' class=('sc-link-verylight',) href='/popular/searches' title='Popular searches'>,
#  <Element 'a' type='button' class=('localeSelector', 'sc-pointer') tabindex='0' aria-haspopup='true' role='button' aria-owns='dropdown-button-76'>]

# %%
len(links), len(new_links)
# Out:
# (9, 169)

# %% [markdown]
# -------

# %% [markdown]
# ## 2) get the text of the new paragraphs now visible in the HTML.

# %%
paragraphs = r.html.find('p')
paragraphs
# Out:
# [<Element 'p' class=('mixedSelectionModule__description', 'sc-type-small', 'sc-type-light')>,
#  <Element 'p' class=('mixedSelectionModule__description', 'sc-type-small', 'sc-type-light')>,
#  <Element 'p' class=('mixedSelectionModule__description', 'sc-type-small', 'sc-type-light')>,
#  <Element 'p' class=('mixedSelectionModule__description', 'sc-type-small', 'sc-type-light')>,
#  <Element 'p' class=('mixedSelectionModule__description', 'sc-type-small', 'sc-type-light')>,
#  <Element 'p' class=('mixedSelectionModule__description', 'sc-type-small', 'sc-type-light')>,
#  <Element 'p' class=('mixedSelectionModule__description', 'sc-type-small', 'sc-type-light')>,
#  <Element 'p' class=('mixedSelectionModule__description', 'sc-type-small', 'sc-type-light')>]

# %%
for p in paragraphs:
    print(p.text)
# Out:
# Popular playlists from the SoundCloud community
# Popular playlists from the SoundCloud community
# Popular playlists from the SoundCloud community
# Popular playlists from the SoundCloud community
# Popular playlists from the SoundCloud community
# Popular playlists from the SoundCloud community
# Up-and-coming tracks on SoundCloud
# The most played tracks on SoundCloud this week

# %% [markdown]
# ## 3) Trying out a few other tags - what else appears after executing the JavaScript

# %%
r.html.find('div')
# Out:
# [<Element 'div' id='app'>,
#  <Element 'div' class=('header__inner', 'l-container', 'l-fullwidth')>,
#  <Element 'div' class=('header__left',)>,
#  <Element 'div' class=('header__logo', 'left')>,
#  <Element 'div' class=('header__middle',)>,
#  <Element 'div' class=('header__search',) role='search'>,
#  <Element 'div' class=('header__right', 'sc-clearfix')>,
#  <Element 'div' class=('header__loginMenu', 'left')>,
#  <Element 'div' class=('header__upload', 'left')>,
#  <Element 'div' class=('announcements', 'g-z-index-fixed-top', 'g-z-index-header')>,
#  <Element 'div' class=('sc-list-nostyle', 'sc-clearfix')>,
#  <Element 'div' class=('announcements__item', 'sc-clearfix')>,
#  <Element 'div' class=('announcement', 'g-dark', 'm-dismiss-visible')>,
#  <Element 'div' class=('l-container', 'l-content')>,
#  <Element 'div' class=('l-product-banners', 'l-inner-fullwidth')>,
#  <Element 'div' class=('l-container',)>,
#  <Element 'div' >,
#  <Element 'div' id='content' role='main'>,
#  <Element 'div' >,
#  <Element 'div' class=('l-fluid-fixed',)>,
#  <Element 'div' class=('sc-border-light-right', 'l-main')>,
#  <Element 'div' class=('l-tabs',)>,
#  <Element 'div' class=('l-content',)>,
#  <Element 'div' data-test-id='home' class=('modular-home-mixed-selection', 'lazyLoadingList')>,
#  <Element 'div' class=('mixedSelectionModule',)>,
#  <Element 'div' class=('mixedSelectionModule__title',)>,
#  <Element 'div' class=('mixedSelectionGallery', 'tileGallery', 'm-fourPanels', 'm-hasItemsForward', 'm-transitionsEnabled')>,
#  <Element 'div' class=('tileGallery__slider--normal',)>,
#  <Element 'div' class=('tileGallery__sliderPeekContainer',)>,
#  <Element 'div' class=('tileGallery__sliderPanel',)>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='0'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-3', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='1'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-6', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='2'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-2', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='3'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-6', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='4'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-10', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='5'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='6'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='7'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='8'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='9'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='10'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='11'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='12'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='13'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='14'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='15'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='16'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='17'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='18'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='19'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='20'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='21'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='22'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='23'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='24'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='25'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='26'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='27'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='28'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='29'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='30'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='31'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='32'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='33'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='34'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='35'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='36'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='37'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='38'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='39'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='40'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='41'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='42'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='43'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='44'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='45'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='46'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='47'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='48'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='49'>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekForward')>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekBackward')>,
#  <Element 'div' class=('mixedSelectionModule__context',)>,
#  <Element 'div' class=('mixedSelectionModule',)>,
#  <Element 'div' class=('mixedSelectionModule__title',)>,
#  <Element 'div' class=('mixedSelectionGallery', 'tileGallery', 'm-fourPanels', 'm-hasItemsForward', 'm-transitionsEnabled')>,
#  <Element 'div' class=('tileGallery__slider--normal',)>,
#  <Element 'div' class=('tileGallery__sliderPeekContainer',)>,
#  <Element 'div' class=('tileGallery__sliderPanel',)>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='0'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-3', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='1'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-8', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='2'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-6', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='3'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-7', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='4'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-2', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='5'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='6'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='7'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='8'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='9'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='10'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='11'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='12'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='13'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='14'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='15'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='16'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='17'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='18'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='19'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='20'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='21'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='22'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='23'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='24'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='25'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='26'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='27'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='28'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='29'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='30'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='31'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='32'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='33'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='34'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='35'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='36'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='37'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='38'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='39'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='40'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='41'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='42'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='43'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='44'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='45'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='46'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='47'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='48'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='49'>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekForward')>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekBackward')>,
#  <Element 'div' class=('mixedSelectionModule__context',)>,
#  <Element 'div' class=('mixedSelectionModule',)>,
#  <Element 'div' class=('mixedSelectionModule__title',)>,
#  <Element 'div' class=('mixedSelectionGallery', 'tileGallery', 'm-fourPanels', 'm-hasItemsForward', 'm-transitionsEnabled')>,
#  <Element 'div' class=('tileGallery__slider--normal',)>,
#  <Element 'div' class=('tileGallery__sliderPeekContainer',)>,
#  <Element 'div' class=('tileGallery__sliderPanel',)>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='0'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-0', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='1'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-3', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='2'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'sc-artwork', 'sc-artwork-placeholder-9') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='3'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-0', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='4'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-6', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='5'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='6'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='7'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='8'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='9'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='10'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='11'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='12'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='13'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='14'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='15'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='16'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='17'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='18'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='19'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='20'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='21'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='22'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='23'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='24'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='25'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='26'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='27'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='28'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='29'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='30'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='31'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='32'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='33'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='34'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='35'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='36'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='37'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='38'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='39'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='40'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='41'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='42'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='43'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='44'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='45'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='46'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='47'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='48'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='49'>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekForward')>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekBackward')>,
#  <Element 'div' class=('mixedSelectionModule__context',)>,
#  <Element 'div' class=('mixedSelectionModule',)>,
#  <Element 'div' class=('mixedSelectionModule__title',)>,
#  <Element 'div' class=('mixedSelectionGallery', 'tileGallery', 'm-fourPanels', 'm-hasItemsForward', 'm-transitionsEnabled')>,
#  <Element 'div' class=('tileGallery__slider--normal',)>,
#  <Element 'div' class=('tileGallery__sliderPeekContainer',)>,
#  <Element 'div' class=('tileGallery__sliderPanel',)>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='0'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-0', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='1'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'sc-artwork', 'sc-artwork-placeholder-5') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='2'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-1', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='3'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-1', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='4'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-11', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='5'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='6'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='7'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='8'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='9'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='10'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='11'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='12'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='13'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='14'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='15'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='16'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='17'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='18'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='19'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='20'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='21'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='22'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='23'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='24'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='25'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='26'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='27'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='28'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='29'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='30'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='31'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='32'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='33'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='34'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='35'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='36'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='37'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='38'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='39'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='40'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='41'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='42'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='43'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='44'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='45'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='46'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='47'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='48'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='49'>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekForward')>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekBackward')>,
#  <Element 'div' class=('mixedSelectionModule__context',)>,
#  <Element 'div' class=('mixedSelectionModule',)>,
#  <Element 'div' class=('mixedSelectionModule__title',)>,
#  <Element 'div' class=('mixedSelectionGallery', 'tileGallery', 'm-fourPanels', 'm-hasItemsForward', 'm-transitionsEnabled')>,
#  <Element 'div' class=('tileGallery__slider--normal',)>,
#  <Element 'div' class=('tileGallery__sliderPeekContainer',)>,
#  <Element 'div' class=('tileGallery__sliderPanel',)>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='0'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-11', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='1'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-6', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='2'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-1', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='3'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-3', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='4'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-7', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='5'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='6'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='7'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='8'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='9'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='10'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='11'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='12'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='13'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='14'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='15'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='16'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='17'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='18'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='19'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='20'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='21'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='22'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='23'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='24'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='25'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='26'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='27'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='28'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='29'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='30'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='31'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='32'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='33'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='34'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='35'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='36'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='37'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='38'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='39'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='40'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='41'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='42'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='43'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='44'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='45'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='46'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='47'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='48'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='49'>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekForward')>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekBackward')>,
#  <Element 'div' class=('mixedSelectionModule__context',)>,
#  <Element 'div' class=('mixedSelectionModule',)>,
#  <Element 'div' class=('mixedSelectionModule__title',)>,
#  <Element 'div' class=('mixedSelectionGallery', 'tileGallery', 'm-fourPanels', 'm-hasItemsForward', 'm-transitionsEnabled')>,
#  <Element 'div' class=('tileGallery__slider--normal',)>,
#  <Element 'div' class=('tileGallery__sliderPeekContainer',)>,
#  <Element 'div' class=('tileGallery__sliderPanel',)>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='0'>,
#  <Element 'div' data-test-id='user-generated-playlist-tile' class=('audibleTile', 'playableTile') data-description='always' data-playbutton='hover' data-actions='hover'>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-0', 'm-loaded') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'audibleTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__descriptionContainer',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='1'>,
# ...
#  <Element 'div' class=('image', 'm-system-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-7') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='4'>,
#  <Element 'div' data-description='always' data-playbutton='hover' data-actions='hover' data-test-id='system-playlist-tile' class=('systemPlaylistTile', 'playableTile')>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-system-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-1') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='5'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='6'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='7'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='8'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='9'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='10'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='11'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='12'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='13'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='14'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='15'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='16'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='17'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='18'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='19'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='20'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='21'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='22'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='23'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='24'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='25'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='26'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='27'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='28'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='29'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='30'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='31'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='32'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='33'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='34'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='35'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='36'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='37'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='38'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='39'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='40'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='41'>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekForward')>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekBackward')>,
#  <Element 'div' class=('mixedSelectionModule__context',)>,
#  <Element 'div' class=('mixedSelectionModule',)>,
#  <Element 'div' class=('mixedSelectionModule__title',)>,
#  <Element 'div' class=('mixedSelectionGallery', 'tileGallery', 'm-fourPanels', 'm-hasItemsForward', 'm-transitionsEnabled')>,
#  <Element 'div' class=('tileGallery__slider--normal',)>,
#  <Element 'div' class=('tileGallery__sliderPeekContainer',)>,
#  <Element 'div' class=('tileGallery__sliderPanel',)>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='0'>,
#  <Element 'div' data-description='always' data-playbutton='hover' data-actions='hover' data-test-id='system-playlist-tile' class=('systemPlaylistTile', 'playableTile')>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-system-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-9') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='1'>,
#  <Element 'div' data-description='always' data-playbutton='hover' data-actions='hover' data-test-id='system-playlist-tile' class=('systemPlaylistTile', 'playableTile')>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-system-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-3') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='2'>,
#  <Element 'div' data-description='always' data-playbutton='hover' data-actions='hover' data-test-id='system-playlist-tile' class=('systemPlaylistTile', 'playableTile')>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-system-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-1') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='3'>,
#  <Element 'div' data-description='always' data-playbutton='hover' data-actions='hover' data-test-id='system-playlist-tile' class=('systemPlaylistTile', 'playableTile')>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-system-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-9') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='4'>,
#  <Element 'div' data-description='always' data-playbutton='hover' data-actions='hover' data-test-id='system-playlist-tile' class=('systemPlaylistTile', 'playableTile')>,
#  <Element 'div' class=('playableTile__artwork',)>,
#  <Element 'div' class=('playableTile__image',)>,
#  <Element 'div' class=('image', 'm-system-playlist', 'image__lightOutline', 'readOnly', 'customImage', 'sc-artwork', 'sc-artwork-placeholder-4') style='height: 100%; width: 100%;'>,
#  <Element 'div' class=('playableTile__playButton', 'g-z-index-content')>,
#  <Element 'div' class=('playableTile__actions',)>,
#  <Element 'div' class=('playableTile__actionWrapper',)>,
#  <Element 'div' class=('playableTile__description',)>,
#  <Element 'div' class=('playableTile__usernameHeadingContainer', 'sc-type-light', 'sc-font-light')>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='5'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='6'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='7'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='8'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='9'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='10'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='11'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='12'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='13'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='14'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='15'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='16'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='17'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='18'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='19'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='20'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='21'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='22'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='23'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='24'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='25'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='26'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='27'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='28'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='29'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='30'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='31'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='32'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='33'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='34'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='35'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='36'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='37'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='38'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='39'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='40'>,
#  <Element 'div' class=('tileGallery__sliderPanelSlide',) data-tile-index='41'>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekForward')>,
#  <Element 'div' class=('tileGallery__sliderPeek', 'tileGallery__sliderPeekBackward')>,
#  <Element 'div' class=('mixedSelectionModule__context',)>,
#  <Element 'div' class=('l-sidebar-right',)>,
#  <Element 'div' class=('streamSidebar', 'sc-clearfix', 'sc-browsers-enable-gpu') style='top: 70px;'>,
#  <Element 'div' class=('sidebarHeader', 'g-flex-row-centered-spread', 'sc-type-light', 'sc-border-light-bottom')>,
#  <Element 'div' class=('sidebarContent',)>,
#  <Element 'div' class=('mobileAppsButtons', 'sc-clearfix', 'm-sidebar')>,
#  <Element 'div' class=('l-footer', 'sc-text-verylight', 'standard', 'sc-border-light-top')>,
#  <Element 'div' class=('footer__localeSelector',)>,
#  <Element 'div' >,
#  <Element 'div' class=('playControls', 'g-z-index-control-bar')>,
#  <Element 'div' class=('playControls__wrapper', 'l-container', 'l-fullwidth')>,
#  <Element 'div' class=('playControls__queue',)>,
#  <Element 'div' class=('queue',)>,
#  <Element 'div' class=('queue__panel',)>,
#  <Element 'div' class=('queue__title', 'sc-font-light', 'sc-type-medium')>,
#  <Element 'div' class=('queue__scrollable', 'g-scrollable', 'g-scrollable-v') style=' overflow: hidden !important;'>,
#  <Element 'div' class=('queue__scrollableInner', 'g-scrollable-inner') style='height: 0px; overflow-x: hidden; width: 480px; padding-right: 30px;'>,
#  <Element 'div' class=('queue__itemsHeight',) style='background-size: 100% 2016px, auto;'>,
#  <Element 'div' class=('queue__itemsContainer',)>,
#  <Element 'div' class=('queue__dragCover',)>,
#  <Element 'div' class=('playControls__bg',)>,
#  <Element 'div' class=('playControls__elements',)>,
#  <Element 'div' class=('playControls__shuffle', 'playControls__control')>,
#  <Element 'div' class=('playControls__repeat', 'playControls__control')>,
#  <Element 'div' class=('playControls__timeline',)>,
#  <Element 'div' class=('playbackTimeline', 'is-scrubbable', 'm-is-snippet')>,
#  <Element 'div' class=('playbackTimeline__timePassed',)>,
#  <Element 'div' class=('playbackTimeline__progressWrapper',) role='progressbar'>,
#  <Element 'div' class=('playbackTimeline__progressBackground',)>,
#  <Element 'div' class=('playbackTimeline__progressBar',) style='min-width: 0px; width: 0px;'>,
#  <Element 'div' class=('playbackTimeline__progressHandle', 'sc-ir') style='left: 0px;'>,
#  <Element 'div' class=('playbackTimeline__duration',)>,
#  <Element 'div' class=('playbackTimeline__snippetIndicator',)>,
#  <Element 'div' class=('playControls__castControl',)>,
#  <Element 'div' class=('playControls__volume',)>,
#  <Element 'div' class=('volume',) data-level='10'>,
#  <Element 'div' class=('sc-visuallyhidden',)>,
#  <Element 'div' class=('volume__iconWrapper',)>,
#  <Element 'div' class=('sc-hidden',) id='volume__sliderDescription'>,
#  <Element 'div' class=('volume__sliderWrapper',) role='slider' aria-valuemin='0' aria-valuemax='1' aria-label='Volume' aria-valuenow='1'>,
#  <Element 'div' class=('volume__sliderBackground',)>,
#  <Element 'div' class=('volume__sliderProgress',) style='height: 92px;'>,
#  <Element 'div' class=('volume__sliderHandle',) style='top: 10px;'>,
#  <Element 'div' class=('playControls__soundBadge',)>,
#  <Element 'div' class=('playbackSoundBadge',)>,
#  <Element 'div' class=('playControls__panel',)>,
#  <Element 'div' class=('playControlsPanel', 'sc-font-body', 'sc-background-darkgrey')>,
#  <Element 'div' class=('uploadTarget', 'modal', 'modalWhiteout', 'g-z-index-modal-background', 'sc-font', 'g-opacity-transition') style='display: none;'>,
#  <Element 'div' class=('uploadTarget__frame',)>,
#  <Element 'div' class=('uploadTarget__title',)>,
#  <Element 'div' class=('uploadTarget__message', 'sc-type-medium', 'sc-text-light')>]

# %%
r.html.links
# Out:
# {'/',
#  '//blog.soundcloud.com',
#  '//creators.soundcloud.com',
#  '/agamidae',
#  '/agamidae/sets/instrumental-7',
#  '/billie-kihega',
#  '/billie-kihega/sets/billies-sleep-sounds',
#  '/capitalcqu',
#  '/capitalcqu/sets/midnight-lofi',
#  '/charts/top',
#  '/digitalstreams',
#  '/digitalstreams/sets/deephousehits',
#  '/discover',
#  '/discover/sets/charts-top:all-music',
#  '/discover/sets/charts-top:alternativerock',
#  '/discover/sets/charts-top:ambient',
#  '/discover/sets/charts-top:classical',
#  '/discover/sets/charts-top:country',
#  '/discover/sets/charts-trending:all-music',
#  '/discover/sets/charts-trending:alternativerock',
#  '/discover/sets/charts-trending:ambient',
#  '/discover/sets/charts-trending:classical',
#  '/discover/sets/charts-trending:country',
#  '/egemannen',
#  '/egemannen/sets/bed-bug-classic-ii',
#  '/fitnation-egypt',
#  '/fitnation-egypt/sets/jointhefitnation',
#  '/goldsgymegypt',
#  '/goldsgymegypt/sets/dubstep-by-golds-gym-egypt',
#  '/ilyanaazman',
#  '/ilyanaazman/sets/tsyn',
#  '/imprint',
#  '/itsulana',
#  '/itsulana/sets/read-more-write-more',
#  '/jafeel',
#  '/jafeel/sets/tomorrowland',
#  '/jean-claude-4',
#  '/jean-claude-4/sets/sleep-healing-sounds',
#  '/lolollov2',
#  '/lolollov2/sets/cosy-night-autumn',
#  '/lovelovesyousoo',
#  '/lovelovesyousoo/sets/beautyinside',
#  '/lovelovesyousoo/sets/jazz-hip',
#  '/lovelovesyousoo/sets/jazzhip7c',
#  '/mightyj-1',
#  '/mightyj-1/sets/morning-chillout',
#  '/mugatunesofficial',
#  '/mugatunesofficial/sets/pure-adrenaline',
#  '/mzn665',
#  '/mzn665/sets/coffeehouse',
#  '/nitza-md',
#  '/nitza-md/sets/piano-deep-concentration',
#  '/pages/cookies',
#  '/pages/privacy',
#  '/partyplaylists69',
#  '/partyplaylists69/sets/workout-2018',
#  '/popular/searches',
#  '/rehab-mohammed',
#  '/rehab-mohammed/sets/relax',
#  '/rehan-khan-55',
#  '/rehan-khan-55/sets/meditation',
#  '/stream',
#  '/teamdr',
#  '/teamdr/sets/noise-basement',
#  '/terms-of-use',
#  '/upload',
#  '/user-610681392',
#  '/user-610681392/sets/summer-2k17',
#  '/user-876658341',
#  '/user-876658341/sets/sunday-morning-kisses-and',
#  '/user-876658341/sets/sunday-music-and-hot-coffee',
#  '/user-961145082',
#  '/user-961145082/sets/as-beautiful-as-it-sounds',
#  '/you/library',
#  'https://itunes.apple.com/us/app/soundcloud/id336353151?mt=8',
#  'https://play.google.com/store/apps/details?id=com.soundcloud.android&hl=us&referrer=utm_source%3Dsoundcloud%26utm_medium%3Dweb%26utm_campaign%3Dweb_xsell_discover_page'}

# %%
r.html.absolute_links
# Out:
# {'https://blog.soundcloud.com',
#  'https://creators.soundcloud.com',
#  'https://itunes.apple.com/us/app/soundcloud/id336353151?mt=8',
#  'https://play.google.com/store/apps/details?id=com.soundcloud.android&hl=us&referrer=utm_source%3Dsoundcloud%26utm_medium%3Dweb%26utm_campaign%3Dweb_xsell_discover_page',
#  'https://soundcloud.com/',
#  'https://soundcloud.com/agamidae',
#  'https://soundcloud.com/agamidae/sets/instrumental-7',
#  'https://soundcloud.com/billie-kihega',
#  'https://soundcloud.com/billie-kihega/sets/billies-sleep-sounds',
#  'https://soundcloud.com/capitalcqu',
#  'https://soundcloud.com/capitalcqu/sets/midnight-lofi',
#  'https://soundcloud.com/charts/top',
#  'https://soundcloud.com/digitalstreams',
#  'https://soundcloud.com/digitalstreams/sets/deephousehits',
#  'https://soundcloud.com/discover',
#  'https://soundcloud.com/discover/sets/charts-top:all-music',
#  'https://soundcloud.com/discover/sets/charts-top:alternativerock',
#  'https://soundcloud.com/discover/sets/charts-top:ambient',
#  'https://soundcloud.com/discover/sets/charts-top:classical',
#  'https://soundcloud.com/discover/sets/charts-top:country',
#  'https://soundcloud.com/discover/sets/charts-trending:all-music',
#  'https://soundcloud.com/discover/sets/charts-trending:alternativerock',
#  'https://soundcloud.com/discover/sets/charts-trending:ambient',
#  'https://soundcloud.com/discover/sets/charts-trending:classical',
#  'https://soundcloud.com/discover/sets/charts-trending:country',
#  'https://soundcloud.com/egemannen',
#  'https://soundcloud.com/egemannen/sets/bed-bug-classic-ii',
#  'https://soundcloud.com/fitnation-egypt',
#  'https://soundcloud.com/fitnation-egypt/sets/jointhefitnation',
#  'https://soundcloud.com/goldsgymegypt',
#  'https://soundcloud.com/goldsgymegypt/sets/dubstep-by-golds-gym-egypt',
#  'https://soundcloud.com/ilyanaazman',
#  'https://soundcloud.com/ilyanaazman/sets/tsyn',
#  'https://soundcloud.com/imprint',
#  'https://soundcloud.com/itsulana',
#  'https://soundcloud.com/itsulana/sets/read-more-write-more',
#  'https://soundcloud.com/jafeel',
#  'https://soundcloud.com/jafeel/sets/tomorrowland',
#  'https://soundcloud.com/jean-claude-4',
#  'https://soundcloud.com/jean-claude-4/sets/sleep-healing-sounds',
#  'https://soundcloud.com/lolollov2',
#  'https://soundcloud.com/lolollov2/sets/cosy-night-autumn',
#  'https://soundcloud.com/lovelovesyousoo',
#  'https://soundcloud.com/lovelovesyousoo/sets/beautyinside',
#  'https://soundcloud.com/lovelovesyousoo/sets/jazz-hip',
#  'https://soundcloud.com/lovelovesyousoo/sets/jazzhip7c',
#  'https://soundcloud.com/mightyj-1',
#  'https://soundcloud.com/mightyj-1/sets/morning-chillout',
#  'https://soundcloud.com/mugatunesofficial',
#  'https://soundcloud.com/mugatunesofficial/sets/pure-adrenaline',
#  'https://soundcloud.com/mzn665',
#  'https://soundcloud.com/mzn665/sets/coffeehouse',
#  'https://soundcloud.com/nitza-md',
#  'https://soundcloud.com/nitza-md/sets/piano-deep-concentration',
#  'https://soundcloud.com/pages/cookies',
#  'https://soundcloud.com/pages/privacy',
#  'https://soundcloud.com/partyplaylists69',
#  'https://soundcloud.com/partyplaylists69/sets/workout-2018',
#  'https://soundcloud.com/popular/searches',
#  'https://soundcloud.com/rehab-mohammed',
#  'https://soundcloud.com/rehab-mohammed/sets/relax',
#  'https://soundcloud.com/rehan-khan-55',
#  'https://soundcloud.com/rehan-khan-55/sets/meditation',
#  'https://soundcloud.com/stream',
#  'https://soundcloud.com/teamdr',
#  'https://soundcloud.com/teamdr/sets/noise-basement',
#  'https://soundcloud.com/terms-of-use',
#  'https://soundcloud.com/upload',
#  'https://soundcloud.com/user-610681392',
#  'https://soundcloud.com/user-610681392/sets/summer-2k17',
#  'https://soundcloud.com/user-876658341',
#  'https://soundcloud.com/user-876658341/sets/sunday-morning-kisses-and',
#  'https://soundcloud.com/user-876658341/sets/sunday-music-and-hot-coffee',
#  'https://soundcloud.com/user-961145082',
#  'https://soundcloud.com/user-961145082/sets/as-beautiful-as-it-sounds',
#  'https://soundcloud.com/you/library'}

# %% [markdown]
# ## 4) Using a CSS selector, extract the meta tag with name = "keywords".

# %%
r.html.find('meta[name=keywords]')
# Out:
# [<Element 'meta' content='record, sounds, share, sound, audio, tracks, music, soundcloud' name='keywords'>]

# %% [markdown]
# ## 5) Links that automatically open to a new a tab are identified by having a "target" attribute equal to "_blank". Try extracting these links and their URLs.

# %%
a_list = r.html.find('a[target=_blank][href]')
a_list
# Out:
# [<Element 'a' href='https://itunes.apple.com/us/app/soundcloud/id336353151?mt=8' target='_blank' class=('mobileAppsButtons__button', 'mobileAppsButtons__appStore', 'g-appStoreButton', 'g-appStoreButton__appStore', 'sc-ir')>,
#  <Element 'a' href='https://play.google.com/store/apps/details?id=com.soundcloud.android&hl=us&referrer=utm_source%3Dsoundcloud%26utm_medium%3Dweb%26utm_campaign%3Dweb_xsell_discover_page' target='_blank' class=('mobileAppsButtons__button', 'mobileAppsButtons__googlePlay', 'g-appStoreButton', 'g-appStoreButton__googlePlay', 'sc-ir')>,
#  <Element 'a' class=('sc-link-verylight',) href='//creators.soundcloud.com' target='_blank' title='Creator Resources'>,
#  <Element 'a' class=('sc-link-verylight',) href='//blog.soundcloud.com' target='_blank' title='SoundCloud blog'>]

# %%
for link in a_list:
    print(link.absolute_links)
# Out:
# {'https://itunes.apple.com/us/app/soundcloud/id336353151?mt=8'}
# {'https://play.google.com/store/apps/details?id=com.soundcloud.android&hl=us&referrer=utm_source%3Dsoundcloud%26utm_medium%3Dweb%26utm_campaign%3Dweb_xsell_discover_page'}
# {'https://creators.soundcloud.com'}
# {'https://blog.soundcloud.com'}
